# %%
from InvTools.ATEM import ATEMdata

# %%
HMdata = ATEMdata('obs_rotate_hm.txt', 'dpred_009_hm.txt')
LMdata = ATEMdata('obs_rotate_lm.txt', 'dpred_006_lm.txt')

# %%
LMdata.df['Moment'] = 'L'
HMdata.df['Moment'] = 'H'
LMdata.df.append(HMdata.df).reset_index(drop=True)
# Out:
#                x           y       z         t  locInd  tInd line  dBdt_X  \
# 0      458944.10  8331419.93   75.10  0.000026       0     0  NaN -9999.0
# 1      458944.10  8331419.93   75.10  0.000033       0     1  NaN -9999.0
# 2      458944.10  8331419.93   75.10  0.000042       0     2  NaN -9999.0
# 3      458944.10  8331419.93   75.10  0.000054       0     3  NaN -9999.0
# 4      458944.10  8331419.93   75.10  0.000068       0     4  NaN -9999.0
# 5      458944.10  8331419.93   75.10  0.000086       0     5  NaN -9999.0
# 6      458944.10  8331419.93   75.10  0.000109       0     6  NaN -9999.0
# 7      458944.10  8331419.93   75.10  0.000137       0     7  NaN -9999.0
# 8      458944.10  8331419.93   75.10  0.000172       0     8  NaN -9999.0
# 9      458944.10  8331419.93   75.10  0.000218       0     9  NaN -9999.0
# 10     458944.10  8331419.93   75.10  0.000275       0    10  NaN -9999.0
# 11     458944.10  8331419.93   75.10  0.000347       0    11  NaN -9999.0
# ...
