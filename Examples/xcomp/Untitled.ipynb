# %%
from InvTools.ATEM import ATEMdata

# %%
data = ATEMdata("obs_DS5_west_topo_XZ.txt", "inv_01_dpredUBC_XZ.txt").df
data
# Out:
#                x          y       z         t  locInd  tInd line  \
# 0      629200.24  857204.78  554.69  0.000036       0     0  NaN
# 1      629200.24  857204.78  554.69  0.000042       0     1  NaN
# 2      629200.24  857204.78  554.69  0.000048       0     2  NaN
# 3      629200.24  857204.78  554.69  0.000055       0     3  NaN
# 4      629200.24  857204.78  554.69  0.000063       0     4  NaN
# 5      629200.24  857204.78  554.69  0.000073       0     5  NaN
# 6      629200.24  857204.78  554.69  0.000083       0     6  NaN
# 7      629200.24  857204.78  554.69  0.000096       0     7  NaN
# 8      629200.24  857204.78  554.69  0.000110       0     8  NaN
# 9      629200.24  857204.78  554.69  0.000126       0     9  NaN
# 10     629200.24  857204.78  554.69  0.000145       0    10  NaN
# 11     629200.24  857204.78  554.69  0.000167       0    11  NaN
# 12     629200.24  857204.78  554.69  0.000192       0    12  NaN
# ...

# %%
import numpy as np
test = np.array([])
test.min()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b39183dfb2d8> in <module>()
#       1 import numpy as np
#       2 test = np.array([])
# ----> 3 test.min()
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity
